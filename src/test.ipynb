# %%
import numpy as np
import pandas as pd

import folium
from folium.plugins import TimestampedGeoJson
from folium.plugins import HeatMap

# %%
war_dataset = pd.read_csv("data/Extra-StateWarData_v4.0.csv", encoding = "ISO-8859-1")
war_dataset.head()
# Out:
#    WarNum                        WarName  WarType  ccode1           SideA  \
# 0     300  Allied Bombardment of Algiers        3     210     Netherlands
# 1     300  Allied Bombardment of Algiers        3     200  United Kingdom
# 2     301                Ottoman-Wahhabi        3     640  Ottoman Empire
# 3     302            Liberation of Chile        2     230           Spain
# 4     303       First Bolivar Expedition        2     230           Spain
#
#    ccode2                       SideB  StartMonth1  StartDay1  StartYear1  \
# 0      -8                          -8            8         26        1816
# 1      -8                     Algeria            8         26        1816
# 2      -8              Saudi Wahhabis            9         -9        1816
# 3      -8  San Martin revolutionaries            1          9        1817
# 4      -8                 New Granada            4         11        1817
#
#    ...  EndYear2  Initiator  Interven  TransFrom  Outcome  TransTo  \
# ...

# %%
min_year = min(war_dataset['Year'])
max_year = max(war_dataset['Year'])

time_index = []
data = []

for year in range(min_year,max_year+1):
    time_index.append(year)
    data.append(war_dataset[war_dataset['Year'] == year][['Latitude','Longitude']].values.tolist())
    
weight = 1# default value
for time_entry in data:
    for row in time_entry:
        row.append(weight)
data
# Out:
# [[[-16.5, -68.15, 1],
#   [12.5, 105.0, 1],
#   [35.0, 110.0, 1],
#   [39.5, 22.5, 1],
#   [0.0, 110.0, 1],
#   [37.0, 46.0, 1],
#   [39.0, 47.0, 1],
#   [32.0, 35.0, 1],
#   [18.0, 104.0, 1],
#   [17.0, 122.0, 1],
#   [59.0, 26.0, 1],
#   [57.0, 25.0, 1],
#   [55.0, 24.0, 1],
#   [49.0, 25.0, 1],
#   [16.0, 105.0, 1],
#   [39.75, 19.75, 1],
#   [17.0, 107.0, 1]],
#  [[12.5, 105.0, 1],
#   [35.0, 110.0, 1],
#   [39.5, 22.5, 1],
#   [0.0, 110.0, 1],
#   [18.0, 104.0, 1],
#   [17.0, 122.0, 1],
#   [59.0, 26.0, 1],
#   [57.0, 25.0, 1],
#   [55.0, 24.0, 1],
#   [49.0, 25.0, 1],
#   [17.0, 107.0, 1],
#   [23.5, 121.0, 1],
#   [17.5, 78.5, 1],
#   [-18.5, 49.0, 1],
#   [-25.27, -57.67, 1]],
#  [[12.5, 105.0, 1],
#   [35.0, 110.0, 1],
#   [39.5, 22.5, 1],
#   [0.0, 110.0, 1],
#   [18.0, 104.0, 1],
#   [17.0, 122.0, 1],
#   [59.0, 26.0, 1],
#   [55.0, 24.0, 1],
#   [49.0, 25.0, 1],
#   [17.0, 107.0, 1],
#   [17.5, 78.5, 1],
#   [34.0, 76.0, 1],
#   [17.0, 97.5, 1],
#   [20.0, 95.0, 1],
# ...

# %%
data
# Out:
# [[[47.504539036025584, 4.292407029209247, 1],
#   [47.69040904564529, 4.252424765823684, 1],
#   [46.56622363785289, 3.1698932994737725, 1],
#   [48.512345988527414, 3.5575115701151936, 1],
#   [47.912356200438545, 4.541688488218782, 1],
#   [47.7449114720645, 6.410987139161764, 1],
#   [49.27575216702049, 3.583654594233588, 1],
#   [47.82845322406549, 3.8219354061097293, 1],
#   [48.04493261439567, 6.31593606743332, 1],
#   [46.476548975848104, 4.6875193522227105, 1],
#   [48.22998111187808, 4.330735827816389, 1],
#   [49.09176755111292, 5.097273923224413, 1],
#   [48.27319149417738, 5.658018973640203, 1],
#   [48.122983644592075, 5.780950867261257, 1],
#   [46.44643679370932, 4.755224680829496, 1],
#   [49.29166945103235, 6.129019031044898, 1],
#   [47.001037365055055, 6.290837811317019, 1],
#   [46.8662712198302, 5.128384470003526, 1],
#   [48.60872159648292, 4.685247191774352, 1],
#   [48.847472424367105, 4.528416690851091, 1],
#   [49.82969363846115, 3.7616826932379714, 1],
# ...

# %%
np.random.seed(3141592)
initial_data = (
    np.random.normal(size=(100, 2)) * np.array([[1, 1]]) +
    np.array([[48, 5]])
)

move_data = np.random.normal(size=(100, 2)) * 0.01

data = [(initial_data + move_data * i).tolist() for i in range(100)]

weight = 1  # default value
for time_entry in data:
    for row in time_entry:
        row.append(weight)

# %%
m = folium.Map(location=[50.77500, 10.23333],zoom_start=1)

hm = plugins.HeatMapWithTime(data,min_opacity=1)

hm.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[50.77500, 10.23333],zoom_start=1) #Initialize map
heatmap = HeatMap(data[30],radius = 10) #Add heatmap data to map
m.add_child(heatmap) #Add heatmap to map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map([48., 5.], tiles='stamentoner', zoom_start=6)

hm = plugins.HeatMapWithTime(data)

hm.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from datetime import datetime, timedelta


time_index = [
    (datetime.now() + k * timedelta(1)).strftime('%Y-%m-%d') for
    k in range(len(data))
]

# %%
m = folium.Map([48., 5.], tiles='stamentoner', zoom_start=6)

hm = plugins.HeatMapWithTime(
    data,
    index=time_index,
    auto_play=True,
    max_opacity=0.3,
    radius = 50
)

hm.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ts = TimestampedGeoJson({
     'type': 'FeatureCollection',
     'features': [
       {
         'type': 'Feature',
         'geometry': {
           'type': 'LineString',
           'coordinates': [[-70,-25],[-70,35],[70,35]],
           },
         'properties': {
           'times': [1435708800000, 1435795200000, 1435881600000]
           }
         },
         {
         'type': 'Feature',
         'geometry': {
           'type': 'LineString',
           'coordinates': [[70,25],[70,45]],
           },
         'properties': {
           'times': [1435708800000, 1435881600000]
           }
         }
       ]
     })

# %%
m = folium.Map(location=[50.77500, 10.23333],zoom_start=1) #Initialize map
m.add_child(ts) #Add heatmap to map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
